# %%
import nltk

# %%
# define a feature extraction function for each name
def gender_features(word):
    return{'last_letter': word[-1]}
print(gender_features('Shrek'))
# Out:
# {'last_letter': 'k'}

# %%
# get the list for male and female first names from nltk
from nltk.corpus import names
print(names.words('male.txt')[:20])
print(names.words('female.txt')[:20])
# Out:
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim', 'Abdullah', 'Abe', 'Abel', 'Abelard', 'Abner', 'Abraham', 'Abram', 'Ace', 'Adair', 'Adam']
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale', 'Abra', 'Acacia', 'Ada', 'Adah', 'Adaline', 'Adara', 'Addie', 'Addis', 'Adel', 'Adela']

# %%
# make list of male and female names paired with gender
namesgender = ([(name, 'male') for name in names.words('male.txt')] +
          [(name, 'female') for name in names.words('female.txt')])
print(len(namesgender))
print(namesgender[:20])   # first 20
print(namesgender[7924:])  # last 20
# Out:
# 7944
# [('Aamir', 'male'), ('Aaron', 'male'), ('Abbey', 'male'), ('Abbie', 'male'), ('Abbot', 'male'), ('Abbott', 'male'), ('Abby', 'male'), ('Abdel', 'male'), ('Abdul', 'male'), ('Abdulkarim', 'male'), ('Abdullah', 'male'), ('Abe', 'male'), ('Abel', 'male'), ('Abelard', 'male'), ('Abner', 'male'), ('Abraham', 'male'), ('Abram', 'male'), ('Ace', 'male'), ('Adair', 'male'), ('Adam', 'male')]
# [('Zena', 'female'), ('Zenia', 'female'), ('Zia', 'female'), ('Zilvia', 'female'), ('Zita', 'female'), ('Zitella', 'female'), ('Zoe', 'female'), ('Zola', 'female'), ('Zonda', 'female'), ('Zondra', 'female'), ('Zonnya', 'female'), ('Zora', 'female'), ('Zorah', 'female'), ('Zorana', 'female'), ('Zorina', 'female'), ('Zorine', 'female'), ('Zsa Zsa', 'female'), ('Zsazsa', 'female'), ('Zulema', 'female'), ('Zuzana', 'female')]

# %%
# put the list into random order
import random
random.shuffle(namesgender)
print(namesgender[:20])
# Out:
# [('Gustav', 'male'), ('Sheba', 'female'), ('Shauna', 'female'), ('Dorelia', 'female'), ('Heath', 'male'), ('Tobias', 'male'), ('Christalle', 'female'), ('Dorey', 'female'), ('Mirabella', 'female'), ('Loren', 'male'), ('Prentice', 'male'), ('Dale', 'female'), ('Donny', 'female'), ('Doria', 'female'), ('Vernen', 'male'), ('Saxe', 'male'), ('Nelson', 'male'), ('Deena', 'female'), ('Christiano', 'male'), ('Emmye', 'female')]

# %%
# featuresets represent each name as features and a label
featuresets = [(gender_features(n), g) for (n, g) in namesgender]
print(featuresets[:20])
# Out:
# [({'last_letter': 'v'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'h'}, 'male'), ({'last_letter': 's'}, 'male'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'y'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'e'}, 'male'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'y'}, 'female'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'e'}, 'male'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'o'}, 'male'), ({'last_letter': 'e'}, 'female')]

# %%
len(train_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4dbb4d14fc00> in <module>()
# ----> 1 len(train_set)
#
# NameError: name 'train_set' is not defined

# %%
# create training and test sets, run a classifier and show the accuracy
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# classify new instances
print(classifier.classify(gender_features('Neo')))
print(classifier.classify(gender_features('Trinity')))

# %%
# classify accuracy function runs the classifier on the test set and reports
#   comparisons between predicted labels and actual/gold labels
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0e757d055ec8> in <module>()
#       1 # classify accuracy function runs the classifier on the test set and reports
#       2 #   comparisons between predicted labels and actual/gold labels
# ----> 3 print(nltk.classify.accuracy(classifier, test_set))
#
# NameError: name 'classifier' is not defined

# %%
# this function available for naive bayes classifiers
print(classifier.show_most_informative_features(20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-68a084658eaa> in <module>()
#       1 # this function available for naive bayes classifiers
# ----> 2 print(classifier.show_most_informative_features(20))
#
# NameError: name 'classifier' is not defined

# %%
# creating lots of features
#   there are probably too many features but we are demonstrating different
#     types of features
def gender_features2(name):
    features = {}
    features["firstletter"] = name[0].lower()
    features["lastletter"] = name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())
    return features

# %%
features = gender_features2('Shrek')
print(len(features))
print(features)
# Out:
# 54
# {'firstletter': 's', 'lastletter': 'k', 'count(a)': 0, 'has(a)': False, 'count(b)': 0, 'has(b)': False, 'count(c)': 0, 'has(c)': False, 'count(d)': 0, 'has(d)': False, 'count(e)': 1, 'has(e)': True, 'count(f)': 0, 'has(f)': False, 'count(g)': 0, 'has(g)': False, 'count(h)': 1, 'has(h)': True, 'count(i)': 0, 'has(i)': False, 'count(j)': 0, 'has(j)': False, 'count(k)': 1, 'has(k)': True, 'count(l)': 0, 'has(l)': False, 'count(m)': 0, 'has(m)': False, 'count(n)': 0, 'has(n)': False, 'count(o)': 0, 'has(o)': False, 'count(p)': 0, 'has(p)': False, 'count(q)': 0, 'has(q)': False, 'count(r)': 1, 'has(r)': True, 'count(s)': 1, 'has(s)': True, 'count(t)': 0, 'has(t)': False, 'count(u)': 0, 'has(u)': False, 'count(v)': 0, 'has(v)': False, 'count(w)': 0, 'has(w)': False, 'count(x)': 0, 'has(x)': False, 'count(y)': 0, 'has(y)': False, 'count(z)': 0, 'has(z)': False}

# %%
# create feature sets using this function
featuresets2 = [(gender_features2(n), g) for (n, g) in namesgender]

# %%
# create new training and test sets, classify and look at accuracy
train_set, test_set = featuresets2[500:], featuresets2[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.758

# %%
# Out:
# 0.762

# %%
# define a function that will compare the classifier labels with the gold standard labels
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

# %%
errors = geterrors(test_names)
print(len(errors))
# Out:
# 119

# %%
# define a function to print the errors
def printerrors(errors):
    for (tag, guess, name) in sorted(errors):
        print('correct={:<8s} guess={:<8s} name={:<30s}'.format(tag, guess, name))

printerrors(errors)
# Out:
# correct=female   guess=male     name=Alis
# correct=female   guess=male     name=Allis
# correct=female   guess=male     name=Allyn
# correct=female   guess=male     name=Averil
# correct=female   guess=male     name=Averyl
# correct=female   guess=male     name=Beau
# correct=female   guess=male     name=Bo
# correct=female   guess=male     name=Cam
# correct=female   guess=male     name=Carmon
# correct=female   guess=male     name=Caroljean
# correct=female   guess=male     name=Cherilynn
# correct=female   guess=male     name=Chriss
# correct=female   guess=male     name=Consuelo
# correct=female   guess=male     name=Coralyn
# correct=female   guess=male     name=Cris
# correct=female   guess=male     name=Darleen
# correct=female   guess=male     name=Darryl
# correct=female   guess=male     name=Diann
# correct=female   guess=male     name=Doro
# correct=female   guess=male     name=Dorris
# correct=female   guess=male     name=Eden
# correct=female   guess=male     name=Ellyn
# correct=female   guess=male     name=Estell
# correct=female   guess=male     name=Farrand
# correct=female   guess=male     name=Gail
# correct=female   guess=male     name=Gertrudis
# correct=female   guess=male     name=Gredel
# correct=female   guess=male     name=Grethel
# correct=female   guess=male     name=Gwendolen
# correct=female   guess=male     name=Hesther
# correct=female   guess=male     name=Jaquelin
# correct=female   guess=male     name=Joslyn
# correct=female   guess=male     name=Karmen
# correct=female   guess=male     name=Kass
# correct=female   guess=male     name=Katlin
# correct=female   guess=male     name=Kit
# correct=female   guess=male     name=Koo
# correct=female   guess=male     name=Kylynn
# correct=female   guess=male     name=Lillis
# correct=female   guess=male     name=Linnell
# correct=female   guess=male     name=Lust
# correct=female   guess=male     name=Madalyn
# correct=female   guess=male     name=Mair
# correct=female   guess=male     name=Marabel
# correct=female   guess=male     name=Margit
# correct=female   guess=male     name=Meridel
# correct=female   guess=male     name=Merilyn
# correct=female   guess=male     name=Mildrid
# correct=female   guess=male     name=Nitin
# correct=female   guess=male     name=Noellyn
# correct=female   guess=male     name=Noreen
# correct=female   guess=male     name=Roz
# correct=female   guess=male     name=Shannen
# correct=female   guess=male     name=Sharleen
# correct=female   guess=male     name=Sharyl
# correct=female   guess=male     name=Sibel
# correct=female   guess=male     name=Sioux
# correct=female   guess=male     name=Suzan
# correct=female   guess=male     name=Ted
# correct=female   guess=male     name=Wren
# correct=female   guess=male     name=Yoko
# correct=male     guess=female   name=Abdullah
# correct=male     guess=female   name=Allie
# correct=male     guess=female   name=Aube
# correct=male     guess=female   name=Bailey
# correct=male     guess=female   name=Beale
# correct=male     guess=female   name=Benjie
# correct=male     guess=female   name=Cary
# correct=male     guess=female   name=Chance
# correct=male     guess=female   name=Charlie
# correct=male     guess=female   name=Chaunce
# correct=male     guess=female   name=Claire
# correct=male     guess=female   name=Connolly
# correct=male     guess=female   name=Davidde
# correct=male     guess=female   name=Elroy
# correct=male     guess=female   name=Enrique
# correct=male     guess=female   name=Felipe
# correct=male     guess=female   name=Gregory
# correct=male     guess=female   name=Harvie
# correct=male     guess=female   name=Hewie
# correct=male     guess=female   name=Iggy
# correct=male     guess=female   name=Jackie
# correct=male     guess=female   name=Jermaine
# correct=male     guess=female   name=Joshua
# correct=male     guess=female   name=Kelsey
# correct=male     guess=female   name=Laurance
# correct=male     guess=female   name=Lonny
# correct=male     guess=female   name=Mace
# correct=male     guess=female   name=Marietta
# correct=male     guess=female   name=Matty
# correct=male     guess=female   name=Maurise
# correct=male     guess=female   name=Mendie
# correct=male     guess=female   name=Murdoch
# correct=male     guess=female   name=Murray
# correct=male     guess=female   name=Nichole
# correct=male     guess=female   name=Nickie
# correct=male     guess=female   name=Ole
# correct=male     guess=female   name=Paddie
# correct=male     guess=female   name=Perry
# correct=male     guess=female   name=Pooh
# correct=male     guess=female   name=Ramsey
# correct=male     guess=female   name=Randie
# correct=male     guess=female   name=Ravi
# correct=male     guess=female   name=Rickie
# correct=male     guess=female   name=Ritchie
# correct=male     guess=female   name=Ronnie
# correct=male     guess=female   name=Sasha
# correct=male     guess=female   name=Scottie
# correct=male     guess=female   name=Shea
# correct=male     guess=female   name=Shelley
# correct=male     guess=female   name=Sonnie
# correct=male     guess=female   name=Tabbie
# correct=male     guess=female   name=Tracy
# correct=male     guess=female   name=Tre
# correct=male     guess=female   name=Tucky
# correct=male     guess=female   name=Tyrone
# correct=male     guess=female   name=Worth
# correct=male     guess=female   name=Zebadiah
# correct=male     guess=female   name=Zechariah

# %%
# evaluation measures showing performance of classifier

from nltk.metrics import *

reflist = []
testlist = []
for (features, label) in test_set:
    reflist.append(label)
    testlist.append(classifier.classify(features))

print(reflist[:30])
print(testlist[:30])
# Out:
# ['female', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'male', 'female', 'male']
# ['female', 'male', 'female', 'female', 'female', 'male', 'female', 'female', 'male', 'male', 'female', 'female', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'male', 'male', 'female', 'female']

# %%
# Confusion matrix gives true positives, false negatives, false positives, and true negatives
#   where we interpret female as "yes" and male as "no"
cm = ConfusionMatrix(reflist, testlist)
print(cm)
# Out:
#        |   f     |
#        |   e     |
#        |   m   m |
#        |   a   a |
#        |   l   l |
#        |   e   e |
# -------+---------+
# female |<260> 61 |
#   male |  58<121>|
# -------+---------+
# (row = reference; col = test)

# %%
# define a set of item identifiers that are gold labels and a set of item identifiers that are predicted labels
# this uses index numbers for the labels

reffemale = set([i for i,label in enumerate(reflist) if label == 'female'])
refmale = set([i for i,label in enumerate(reflist) if label == 'male'])
testfemale = set([i for i,label in enumerate(testlist) if label == 'female'])
testmale = set([i for i,label in enumerate(testlist) if label == 'male'])

print(reffemale)
# Out:
# {0, 2, 3, 4, 5, 6, 10, 11, 12, 13, 14, 15, 16, 17, 19, 20, 21, 22, 23, 24, 28, 32, 33, 35, 37, 38, 39, 40, 41, 44, 46, 47, 49, 50, 52, 53, 56, 58, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 73, 74, 77, 78, 79, 80, 83, 84, 88, 89, 91, 92, 93, 94, 95, 98, 101, 103, 105, 106, 107, 109, 110, 111, 114, 115, 117, 120, 121, 124, 125, 126, 127, 129, 131, 132, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 151, 152, 153, 154, 156, 157, 159, 161, 163, 164, 170, 172, 173, 175, 177, 178, 179, 181, 183, 184, 187, 189, 190, 192, 196, 199, 200, 201, 203, 204, 206, 207, 208, 209, 212, 215, 216, 221, 223, 224, 225, 226, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 249, 253, 254, 256, 257, 259, 261, 262, 263, 266, 269, 272, 273, 274, 275, 277, 280, 282, 283, 284, 286, 288, 289, 290, 293, 295, 296, 299, 300, 302, 303, 304, 306, 307, 308, 310, 311, 312, 313, 314, 315, 317, 318, 320, 322, 323, 324, 325, 327, 328, 329, 331, 332, 333, 338, 339, 340, 341, 342, 344, 345, 347, 349, 350, 351, 354, 356, 358, 359, 361, 362, 363, 364, 365, 366, 367, 369, 371, 373, 374, 375, 376, 377, 380, 381, 382, 383, 389, 390, 391, 393, 394, 395, 396, 397, 398, 399, 400, 402, 406, 408, 409, 410, 411, 412, 413, 414, 415, 418, 421, 422, 424, 426, 427, 429, 430, 431, 432, 433, 435, 436, 438, 439, 441, 445, 448, 449, 450, 452, 453, 454, 455, 458, 459, 460, 461, 463, 464, 465, 466, 467, 468, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 488, 489, 490, 492, 493, 495, 496, 497, 498, 499}

# %%
# compute precision, recall and F-measure for each label

def printmeasures(label, refset, testset):
    print(label, 'precision:', precision(refset, testset))
    print(label, 'recall:', recall(refset, testset)) 
    print(label, 'F-measure:', f_measure(refset, testset))

printmeasures('female', reffemale, testfemale)
printmeasures('male', refmale, testmale)
# Out:
# female precision: 0.8176100628930818
# female recall: 0.8099688473520249
# female F-measure: 0.8137715179968701
# male precision: 0.6648351648351648
# male recall: 0.6759776536312849
# male F-measure: 0.6703601108033241

# %%
# another feature extraction function for the exercise
def gender_features3(word):
    return {'suffix1': word[-1],'suffix2': word[-2]}

print(gender_features3('Shrek'))
# Out:
# {'suffix1': 'k', 'suffix2': 'e'}

# %% [markdown]
# Exercise:
# Define a new feature extraction function that includes features for two-letter suffixes,
# such as the one here:
# ```
# def gender_features3(word):
# return {‘suffix1’: word[-1],‘suffix2’: word[-2]}
# ```
#
# Keep the variables train_names and test_names that define the training and test set.
# Make new train_set and test_set variables. Carry out the classification and look at the
# errors in the test set.
#
# Is this classification more accurate? Can you see error examples that you could use to
# make new features to improve? (You don’t have to do this, just observe it.)
#
# Make a post in the discussion for the Week 8 lab in the blackboard system with your
# original accuracy on the test set and the new accuracy, and you may also make any
# observations that you can about the remaining errors.
#
# If you have time, you can make a new gender_features function that keeps three suffix
# letters, but make allowances if any names are only 2 characters long. Or perhaps a
# gender_features function that uses the first letter and the last two letters.

# %%
#Original method
## Experiment related to lab exercise for today
# go back and separate the names into training and test
train_names = namesgender[500:]
test_names = namesgender[:500]
# use our original features to train a classify and test on the development test set
train_set = [(gender_features(n), g) for (n, g) in train_names]
test_set = [(gender_features(n), g) for (n, g) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# save the classifier accuracy for use in the exercise
print("accuracy for old method: ", nltk.classify.accuracy(classifier, test_set))
# Out:
# accuracy for old method:  0.778

# %%
#Define a new feature extraction function that includes features for two-letter suffixes,
def gender_features3(word):
    return {'suffix1': word[-1],'suffix2': word[-2]}

gender_features3('lebron')
# Out:
# {'suffix1': 'n', 'suffix2': 'o'}

# %%
# make list of male and female names paired with gender
namesgender = ([(name, 'male') for name in names.words('male.txt')] +
          [(name, 'female') for name in names.words('female.txt')])

#shullfe the name gender dataset
random.shuffle(namesgender)

# featuresets represent each name as features and a label
featuresets3 = [(gender_features3(n), g) for (n, g) in namesgender]

# create new training and test sets, classify and look at accuracy
train_set, test_set = featuresets3[500:], featuresets3[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print("accuracy for new method: ", nltk.classify.accuracy(classifier, test_set))

#get the names
train_names = namesgender[500:]
test_names = namesgender[:500]

#check out the errors
def geterrors(test):
    errors = []
    for (name, tag) in test:
        guess = classifier.classify(gender_features3(name))
        if guess != tag:
            errors.append( (tag, guess, name) )
    return errors

errors = geterrors(test_names)

def printerrors(errors):
    for (tag, guess, name) in sorted(errors):
        print('correct={} guess={} name={}'.format(tag, guess, name))

printerrors(errors)
# Out:
# accuracy for new method:  0.77
# correct=female guess=male name=Ajay
# correct=female guess=male name=Ashlen
# correct=female guess=male name=Aurel
# correct=female guess=male name=Avivah
# correct=female guess=male name=Carmen
# correct=female guess=male name=Carmon
# correct=female guess=male name=Cass
# correct=female guess=male name=Christin
# correct=female guess=male name=Coreen
# correct=female guess=male name=Corliss
# correct=female guess=male name=Dacy
# correct=female guess=male name=Daffy
# correct=female guess=male name=Dew
# correct=female guess=male name=Elizabet
# correct=female guess=male name=Gay
# correct=female guess=male name=Gillan
# correct=female guess=male name=Ginnifer
# correct=female guess=male name=Gwendolen
# correct=female guess=male name=Ingaberg
# correct=female guess=male name=Ingeberg
# correct=female guess=male name=Isador
# correct=female guess=male name=Janean
# correct=female guess=male name=Janis
# correct=female guess=male name=Jewel
# correct=female guess=male name=Jordain
# correct=female guess=male name=Keren
# correct=female guess=male name=Kip
# correct=female guess=male name=Kipp
# correct=female guess=male name=Kyrstin
# correct=female guess=male name=Lilas
# correct=female guess=male name=Lilian
# correct=female guess=male name=Lilias
# correct=female guess=male name=Lyndsey
# correct=female guess=male name=Mabel
# correct=female guess=male name=Mair
# correct=female guess=male name=Margit
# correct=female guess=male name=Marigold
# correct=female guess=male name=Meriel
# correct=female guess=male name=Mildred
# correct=female guess=male name=Miriam
# correct=female guess=male name=Nadeen
# correct=female guess=male name=Ninon
# correct=female guess=male name=Oprah
# correct=female guess=male name=Ranique
# correct=female guess=male name=Sean
# correct=female guess=male name=Sharon
# correct=female guess=male name=Sib
# correct=female guess=male name=Venus
# correct=male guess=female name=Ajai
# correct=male guess=female name=Andre
# correct=male guess=female name=Barrett
# correct=male guess=female name=Barth
# correct=male guess=female name=Bartie
# correct=male guess=female name=Bernie
# correct=male guess=female name=Bobbie
# correct=male guess=female name=Bobby
# correct=male guess=female name=Brice
# correct=male guess=female name=Brody
# correct=male guess=female name=Chance
# correct=male guess=female name=Chane
# correct=male guess=female name=Clemmie
# correct=male guess=female name=Cobby
# correct=male guess=female name=Deryl
# correct=male guess=female name=Earle
# correct=male guess=female name=Elwyn
# correct=male guess=female name=Flinn
# correct=male guess=female name=Fons
# correct=male guess=female name=Grove
# correct=male guess=female name=Hamil
# correct=male guess=female name=Hartwell
# correct=male guess=female name=Hasty
# correct=male guess=female name=Izzy
# correct=male guess=female name=Jens
# correct=male guess=female name=Jerome
# correct=male guess=female name=Jerzy
# correct=male guess=female name=Johnny
# correct=male guess=female name=Jose
# correct=male guess=female name=Kyle
# correct=male guess=female name=Marietta
# correct=male guess=female name=Martie
# correct=male guess=female name=Mattie
# correct=male guess=female name=Maxwell
# correct=male guess=female name=Merle
# correct=male guess=female name=Michele
# correct=male guess=female name=Mordecai
# correct=male guess=female name=Neddie
# correct=male guess=female name=Neddy
# correct=male guess=female name=Nevil
# correct=male guess=female name=Nevins
# correct=male guess=female name=Ole
# correct=male guess=female name=Osborne
# correct=male guess=female name=Perry
# correct=male guess=female name=Prince
# correct=male guess=female name=Rudie
# correct=male guess=female name=Sammy
# correct=male guess=female name=Shurlocke
# correct=male guess=female name=Sinclare
# correct=male guess=female name=Skelly
# correct=male guess=female name=Stu
# correct=male guess=female name=Tarrant
# correct=male guess=female name=Terrence
# correct=male guess=female name=Terry
# correct=male guess=female name=Thane
# correct=male guess=female name=Toby
# correct=male guess=female name=Toddie
# correct=male guess=female name=Tye
# correct=male guess=female name=Tymothy
# correct=male guess=female name=Vasily
# correct=male guess=female name=Wadsworth
# correct=male guess=female name=Wendell
# correct=male guess=female name=Westbrooke
# correct=male guess=female name=Willmott
# correct=male guess=female name=Winn
# correct=male guess=female name=Wittie
# correct=male guess=female name=Yale

# %%
# Out:
# [({'suffix1': 'n', 'suffix2': 'w'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'u'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'x', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'v'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'k'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'v'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'u', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'k'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'c', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'j'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'u', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'g', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'f'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'z'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'v'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'x'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'k'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'k'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'female'),
#  ({'suffix1': 'p', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'u', 'suffix2': 'h'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'g'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'p'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'g'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'z', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'k'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'y'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'p'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'w', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'u'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'k', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'v'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'K'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'm'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'o'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'g'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'c', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'g'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'g'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'h'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'L'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'p'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'o'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'b'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'h'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'z'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'S'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'u', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'v'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'z'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'u'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'k'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'g'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'w', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'x'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'x', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'p'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'y'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'w', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'v', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'y'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'v'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'k', 'suffix2': 'o'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'z', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'k'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'k'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'y'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'h'}, 'female'),
#  ({'suffix1': 'm', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'h', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 'g'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'm'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'f'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'b', 'suffix2': 'm'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'z'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'o', 'suffix2': 'g'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'c'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'h'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'f'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'a'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 't', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'd'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'v'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'b'}, 'female'),
#  ({'suffix1': 'h', 'suffix2': 's'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'x'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'r', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'm'}, 'male'),
#  ({'suffix1': 'n', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'l'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'o'}, 'male'),
#  ({'suffix1': 's', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 't'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'i', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'c'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'l', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'g', 'suffix2': 'g'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 't', 'suffix2': 'n'}, 'male'),
#  ({'suffix1': 'i', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 't'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'd', 'suffix2': 'r'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 's', 'suffix2': 'a'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'e'}, 'male'),
#  ({'suffix1': 'y', 'suffix2': 'r'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 's'}, 'female'),
#  ({'suffix1': 'e', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'y', 'suffix2': 'd'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'n', 'suffix2': 'e'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'l'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'i'}, 'female'),
#  ({'suffix1': 'o', 'suffix2': 'i'}, 'male'),
#  ({'suffix1': 'r', 'suffix2': 'u'}, 'male'),
#  ({'suffix1': 'a', 'suffix2': 'n'}, 'female'),
#  ({'suffix1': 'a', 'suffix2': 'r'}, 'female'),
#  ...]
